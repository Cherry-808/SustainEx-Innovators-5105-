# %%
# 第二个代码块: 导入需要的库
import pandas as pd
from anthropic import Anthropic
import json
from datetime import datetime
import os

# %%
# 第三个代码块: 定义主要类
class ESGReportGenerator:
    def __init__(self, api_key):
        self.anthropic = Anthropic(api_key=api_key)
        
    def read_csv(self, file_path):
        """读取CSV文件"""
        try:
            df = pd.read_csv(file_path)
            return df.to_dict(orient='records')
        except Exception as e:
            raise Exception(f"读取CSV文件失败: {str(e)}")
            
    def generate_report(self, data):
        """生成ESG评分报告"""
        prompt = f"""我有一份ESG数据,请对其进行分析并生成评分报告和可视化。

数据内容:
{json.dumps(data, ensure_ascii=False, indent=2)}

请提供:
1. 详细的评分标准(包括环境、社会和治理三个维度)
2. 具体的评分结果
3. 一个React组件用于可视化展示结果(使用Recharts绘制图表)
4. 详细的分析报告(包括优势、不足和改进建议)

评分报告要求:
- 基于新加坡交易所(SGX)的可持续发展指标
- 提供明确的评分依据
- 包含量化和定性分析
- 针对新能源行业特点

请确保React组件代码可以直接运行,使用Tailwind CSS进行样式设置。
"""

        try:
            response = self.anthropic.messages.create(
                model="claude-3-5-sonnet-20241022",
                max_tokens=4096,
                messages=[
                    {
                        "role": "user",
                        "content": prompt
                    }
                ]
            )
            return response.content[0].text
        except Exception as e:
            raise Exception(f"生成报告失败: {str(e)}")
            
    def save_report(self, report, output_dir="reports"):
        """保存报告到文件"""
        try:
            if not os.path.exists(output_dir):
                os.makedirs(output_dir)
                
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            filename = f"esg_report_{timestamp}.json"
            filepath = os.path.join(output_dir, filename)
            
            with open(filepath, 'w', encoding='utf-8') as f:
                json.dump({
                    'content': report,
                    'generated_at': timestamp
                }, f, ensure_ascii=False, indent=2)
                
            return filepath
        except Exception as e:
            raise Exception(f"保存报告失败: {str(e)}")

# %%
# 第四个代码块: 使用示例
# 替换为您的 API key
api_key = "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"  

# CSV文件路径
csv_file_path = "train_label2.csv"  # 替换为您的CSV文件路径

# 初始化生成器
generator = ESGReportGenerator(api_key)

# 读取CSV数据
data = generator.read_csv(csv_file_path)

# 生成报告
report = generator.generate_report(data)

# 保存报告
filepath = generator.save_report(report)

print(f"报告已保存至: {filepath}")

# 显示报告内容
print("\nESG评分报告内容:")
print(report)
# Out:
# 报告已保存至: reports\esg_report_20241111_161229.json
#
# ESG评分报告内容:
# 好的,我来帮你完成这个ESG分析评分任务。
#
# 1. 评分标准设计:
#
# ```javascript
# const scoringCriteria = {
#   environmental: {
#     ghgEmissions: { weight: 20, max: 100 },
#     energyEfficiency: { weight: 15, max: 100 },
#     waterManagement: { weight: 15, max: 100 },
#     wasteManagement: { weight: 10, max: 100 }
#   },
#   social: {
#     healthAndSafety: { weight: 15, max: 100 },
#     training: { weight: 10, max: 100 },
#     laborPractices: { weight: 5, max: 100 }
#   },
#   governance: {
#     transparency: { weight: 5, max: 100 },
#     compliance: { weight: 5, max: 100 }
#   }
# };
# ```
#
# 2. 评分结果:
#
# 环境维度: 78/100
# - GHG减排表现优秀,2023年较2020年下降显著
# - 能源消耗持续降低
# - 水资源管理有待改进
# - 废弃物管理体系完善
#
# 社会维度: 82/100
# - 职业健康安全指标良好
# - 培训完成率高
# - 劳工实践符合标准
#
# 治理维度: 85/100
# - ESG信息披露完整
# - 内部控制体系健全
# - 合规管理到位
#
# 总分: 80/100 (优秀)
#
# 3. React可视化组件:
#
# ```jsx
# import { RadarChart, PolarGrid, PolarAngleAxis, Radar } from 'recharts';
#
# const ESGScoreChart = () => {
#   const data = [
#     { subject: 'GHG排放', score: 78 },
#     { subject: '能源效率', score: 75 },
#     { subject: '水资源', score: 70 },
#     { subject: '废弃物', score: 85 },
#     { subject: '健康安全', score: 82 },
#     { subject: '培训', score: 90 },
#     { subject: '治理', score: 85 }
#   ];
#
#   return (
#     <div className="w-full max-w-2xl mx-auto">
#       <RadarChart width={500} height={400} data={data}>
#         <PolarGrid />
#         <PolarAngleAxis dataKey="subject" />
#         <Radar
#           name="ESG Score"
#           dataKey="score"
#           stroke="#8884d8"
#           fill="#8884d8"
#           fillOpacity={0.6}
#         />
#       </RadarChart>
#     </div>
#   );
# };
# ```
#
# 4. 详细分析报告:
#
# 优势:
# 1. 碳排放管理表现突出:
# - 2023年发电碳排放强度降至11gCO2/kWh
# - 比2020基准年下降89%
# - 领先于行业平均水平
#
# 2. 能源效率持续提升:
# - 集团能耗从2021年的44,113GJ降至2023年的34,113GJ
# - 三年累计下降22.7%
#
# 3. 职业健康安全管理完善:
# - TRIR和LTIR指标保持低位
# - 2023年无重大安全事故
# - 培训覆盖率>90%
#
# 不足:
# 1. 水资源管理有待加强:
# - 取水量波动较大
# - 缺乏详细的节水目标
# - 水压力区域用水需关注
#
# 2. 供应链ESG管理:
# - 生物质供应链碳足迹偏高
# - 供应商ESG评估体系待完善
#
# 改进建议:
# 1. 设立更具体的水资源管理目标
# 2. 加强供应商ESG管理
# 3. 增加可再生能源使用比例
# 4. 建立更完善的ESG风险管理体系
# 5. 加强利益相关方沟通
#
# 总体而言,该公司ESG表现优秀,特别是在碳减排方面取得显著成效。建议进一步加强水资源管理和供应链ESG管理,持续提升可持续发展水平。
#
# 这份报告基于SGX标准,结合新能源行业特点,通过定量和定性分析给出评价。评分标准透明,数据支撑充分,建议具有可操作性。
