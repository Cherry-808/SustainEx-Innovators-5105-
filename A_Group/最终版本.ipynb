# %%
import configparser
import os
import fitz  # PyMuPDF
from PIL import Image

# 读取配置文件
config = configparser.ConfigParser()
current_path = os.getcwd()
config.read(os.path.join(current_path, 'config.ini'))

input_path = config['DEFAULT']['Input-Path']
output_path = config['DEFAULT']['Output-Path']
debug = config['DEFAULT'].getboolean('Debug')

# 确保输入和输出路径存在
if not os.path.exists(input_path):
    print(f"Input path does not exist: {input_path}")
    raise FileNotFoundError(f"Input path does not exist: {input_path}")

if not os.path.exists(output_path):
    os.makedirs(output_path)
    print(f"Created output directory: {output_path}")

# 定义提取图片的函数
def extract_images_from_pdf(pdf_path, output_folder):
    try:
        pdf_document = fitz.open(pdf_path)
    except Exception as e:
        print(f"Failed to open PDF file {pdf_path}: {e}")
        return

    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        if debug:
            print(f"Created folder: {output_folder}")

    for page_num in range(len(pdf_document)):
        page = pdf_document.load_page(page_num)
        image_list = page.get_images(full=True)

        if not image_list:
            if debug:
                print(f"No images found on page {page_num + 1}.")
            continue

        for image_index, img in enumerate(image_list):
            xref = img[0]
            try:
                base_image = pdf_document.extract_image(xref)
                image_bytes = base_image["image"]
                image_ext = base_image["ext"]
                # 使用 page_num 和 image_index 确保文件名唯一
                image_name = f"image_{page_num + 1}_{image_index + 1}.{image_ext}"
                image_path = os.path.join(output_folder, image_name)

                with open(image_path, "wb") as image_file:
                    image_file.write(image_bytes)
                print(f"Saved image: {image_path}")

            except Exception as e:
                print(f"Failed to extract image {image_index + 1} on page {page_num + 1}: {e}")

# 定义渲染页面为图像的函数
def render_pdf_page_as_image(pdf_path, output_folder, zoom=2):
    try:
        pdf_document = fitz.open(pdf_path)
    except Exception as e:
        print(f"Failed to open PDF file {pdf_path}: {e}")
        return

    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        if debug:
            print(f"Created folder: {output_folder}")

    for page_num in range(len(pdf_document)):
        page = pdf_document.load_page(page_num)
        mat = fitz.Matrix(zoom, zoom)  # 放大倍率
        try:
            pix = page.get_pixmap(matrix=mat)
            image_name = f"page_{page_num + 1}.png"
            image_path = os.path.join(output_folder, image_name)
            pix.save(image_path)
            print(f"Rendered page {page_num + 1} as image: {image_path}")
        except Exception as e:
            print(f"Failed to render page {page_num + 1}: {e}")

# 获取 input_path 目录中的所有 PDF 文件
pdf_files = [f for f in os.listdir(input_path) if f.lower().endswith('.pdf')]

if not pdf_files:
    print("No PDF files found in the input directory.")
else:
    print(f"Found {len(pdf_files)} PDF file(s) in the input directory.")

# 对每个 PDF 文件进行图片提取和页面渲染
for pdf_file in pdf_files:
    pdf_path = os.path.join(input_path, pdf_file)

    # 为每个 PDF 创建单独的文件夹
    pdf_base_name = os.path.splitext(pdf_file)[0]
    images_output_folder = os.path.join(output_path, pdf_base_name, "extracted_images")
    rendered_pages_folder = os.path.join(output_path, pdf_base_name, "rendered_pages")

    print(f"\nProcessing PDF: {pdf_file}")

    # 提取图片
    print("Extracting images...")
    extract_images_from_pdf(pdf_path, images_output_folder)

    # 渲染页面为图像
    print("Rendering pages as images...")
    render_pdf_page_as_image(pdf_path, rendered_pages_folder, zoom=2)

    print(f"Completed processing {pdf_file}\n")

print("All PDF files have been processed.")

# %%
import os
import base64
import json
from dotenv import load_dotenv
import openai
import re

from openai import OpenAI

# Load environment variables if needed
load_dotenv()

# API setup
client = OpenAI(
    api_key=os.getenv("API_KEY", "your_default_api_key"),
    base_url=os.getenv("BASE_URL", "https://api.openai.com/v1")
)

model_name = "gpt-4o"

# Create output directory if it doesn't exist
os.makedirs(model_name, exist_ok=True)
json_output_path = f"{model_name}/extracted_data.json"

# Path to your extracted images
extracted_images_dir = r'.\output\CDL Hospitality report 2021\rendered_pages'


def encode_image(image_path):
    try:
        with open(image_path, "rb") as image_file:
            return base64.b64encode(image_file.read()).decode('utf-8')
    except Exception as e:
        print(f"Error encoding image {image_path}: {e}")
        return None


system_prompt = 'You are an OCR engineer'
text_content = 'Extract all text content from the document'
text_content2 = '''Extract data information from the text and convert it into JSON format'''


extracted_data_list = []

if os.path.exists(extracted_images_dir):
    file_names = [file_name for file_name in os.listdir(extracted_images_dir) if
                  re.match(r'page_(\d+)\.png', file_name)]
    sorted_file_names = sorted(file_names, key=lambda x: int(re.search(r'(\d+)', x).group()))

    for file_name in sorted_file_names:
        image_path = os.path.join(extracted_images_dir, file_name)
        print(f"Processing file: {file_name}")  # Print the current page being processed

        if not os.path.isfile(image_path):
            print(f"File not found: {image_path}")
            continue

        base64_image = encode_image(image_path)
        if not base64_image:
            print(f"Skipping {file_name} due to encoding error.")
            continue

        try:
            messages = [
                {"role": "system", "content": system_prompt},
                {
                    "role": "user",
                    "content": [
                        {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{base64_image}"}},
                        {"type": "text", "text": text_content},
                    ],
                },
            ]

            resp = client.chat.completions.create(
                model=model_name,
                messages=messages,
                temperature=0.0
            )

            extracted_data = resp.choices[0].message.content

        except Exception as e:
            print(f"Error during completion for {file_name}: {e}")
            continue

        try:
            resp = client.chat.completions.create(
                model=model_name,
                response_format={"type": "json_object"},
                messages=[
                    {"role": "system", "content": text_content2},
                    {"role": "user", "content": [{"type": "text", "text": extracted_data}]},
                ],
                temperature=0.0,
            )

            extracted_data_json = resp.choices[0].message.content
            print(f"Extracted JSON for {file_name}: {extracted_data_json}")  # Print the content of extracted_data_json
            data = json.loads(extracted_data_json)
            extracted_data_list.append({file_name: data})  # Append to list for JSON file saving

        except Exception as e:
            print(f"Error processing JSON for {file_name}: {e}")
            continue

# Save extracted data as JSON file
with open(json_output_path, 'w', encoding='utf-8') as json_file:
    json.dump(extracted_data_list, json_file, ensure_ascii=False, indent=4)

print(f"JSON data saved to {json_output_path}")
# Out:
# Python-dotenv could not parse statement starting at line 2
# Processing file: page_1.png
# Extracted JSON for page_1.png: {
#   "report": {
#     "title": "Sustainability Report",
#     "financial_year": "FY 2021",
#     "end_date": "31 December 2021",
#     "issuer": "CDL Hospitality Trusts",
#     "board_statement": {
#       "commitment": "Instilling sustainability into CDLHT’s core values",
#       "oversight": "Sustainability strategy, performance monitoring, practices, initiatives, and targets",
#       "compliance": "SGX guidelines",
#       "ESG_factors": "Environmental, Social and Governance"
#     },
#     "pandemic_impact": {
#       "business_disruptions": "Challenging for the hospitality industry",
#       "commitment": "Monitoring and managing impacts to the environment and society"
#     },
#     "properties_included": [
#       "Claymore Connect",
#       "Ibis Perth",
#       "Mercure Perth"
#     ],
#     "environmental_stewardship": {
#       "energy_efficiency": "Implementation of curbing initiatives",
#       "resource_management": "Effective management of natural resources consumption",
#       "waste_management": "Monitoring, tracking, and managing waste generation",
#       "data_segregation": "Electricity and fuel data"
#     },
#     "corporate_governance": {
#       "compliance": "Country-specific regulations and standards",
#       "integrity": "Strong corporate governance and responsible business conduct"
#     },
#     "stakeholder_wellbeing": {
#       "safety": "Wellbeing, health, and safety of employees and hotel guests",
#       "community_engagement": "Partnerships with local charitable and social organisations"
#     },
#     "future_goals": "Improving environmental, economic, and social footprint"
#   },
#   "about_report": {
#     "edition": "Fifth Sustainability Report",
#     "assets_under_management": "$2.9 billion",
#     "listing": "Singapore Exchange Securities Trading Limited since 2006",
#     "components": [
#       "CDL Hospitality Real Estate Investment Trust (H-REIT)",
#       "CDL Hospitality Business Trust (HBT)"
#     ],
#     "investment_strategy": {
#       "H-REIT": "Invest in a diversified portfolio of income-producing real estate for hospitality purposes",
#       "HBT": "Invest in a diversified portfolio of real estate or development projects for hospitality purposes"
#     },
#     "managers": {
#       "H-REIT_Manager": "M&C REIT Management Limited",
#       "HBT_Trustee_Manager": "M&C Business Trust Management Limited"
#     }
#   }
# }
# Processing file: page_2.png
# Extracted JSON for page_2.png: {
#   "report": {
#     "title": "Annual Report 2021",
#     "type": "Sustainability Report",
#     "reporting_period": "FY 2021",
#     "scope": {
#       "properties_included": [
#         "Orchard Hotel",
#         "Grand Copthorne Waterfront Hotel",
#         "M Hotel",
#         "Copthorne King’s Hotel",
#         "Studio M Hotel",
#         "W Singapore – Sentosa Cove",
#         "Claymore Connect (Retail mall)",
#         "Pullman Hotel Munich",
#         "The Lowry Hotel",
#         "Hilton Cambridge City Centre",
#         "Grand Millennium Auckland",
#         "Raffles Maldives Meradhoo",
#         "Angsana Velavaru",
#         "Hotel MyStays Asakusabashi",
#         "Hotel MyStays Kamata",
#         "Hotel Cerretani Firenze - MGallery",
#         "Mercure Perth",
#         "Ibis Perth"
#       ],
#       "new_inclusions": [
#         "Claymore Connect",
#         "Ibis Perth",
#         "Mercure Perth"
#       ],
#       "total_properties": 18
#     },
#     "locations": {
#       "Singapore": [
#         "Copthorne King’s Hotel"
#       ],
#       "Germany": [
#         "Pullman Hotel Munich"
#       ],
#       "United Kingdom": [
#         "The Lowry Hotel"
#       ],
#       "New Zealand": [
#         "Grand Millennium Auckland"
#       ],
#       "Maldives": [
#         "Raffles Maldives Meradhoo"
#       ],
#       "Japan": [
#         "Hotel MyStays Asakusabashi"
#       ],
#       "Italy": [
#         "Hotel Cerretani Firenze - MGallery"
#       ],
#       "Australia": [
#         "Mercure Perth"
#       ]
#     },
#     "framework": {
#       "revamp_year": "FY 2021",
#       "pillars": [
#         "Climate Resilience and Environmental Stewardship",
#         "Responsible Investment and Sustainable Value",
#         "Good Governance and Ethical Business",
#         "Enable Inclusiveness, Safety, Growth and Diversity of Our People",
#         "Engage Local Communities and Advocate for Positive Impact"
#       ]
#     }
#   }
# }
# Processing file: page_3.png
# Extracted JSON for page_3.png: {
#   "SustainabilityReport": {
#     "Framework": "United Nations Sustainable Development Goals (UN SDGs)",
#     "ESGPillars": [
#       {
#         "Name": "Climate Resilience and Environmental Stewardship",
#         "SustainableDevelopmentGoals": ["SDG 13"],
#         "OverarchingAmbitions": [
#           "Understand and manage our climate opportunities and risks",
#           "Advocate, enable and enhance resource efficiencies in our portfolio"
#         ],
#         "RelevantMaterialTopics": [
#           "Energy Efficiency",
#           "Water Stewardship",
#           "Waste",
#           "Emissions Reduction",
#           "Climate Action and Resilience"
#         ]
#       },
#       {
#         "Name": "Responsible Investment and Sustainable Value",
#         "SustainableDevelopmentGoals": ["SDG 8"],
#         "OverarchingAmbitions": [
#           "Implement responsible investment practices",
#           "Create economic value for stakeholders"
#         ],
#         "RelevantMaterialTopics": [
#           "Economic Performance",
#           "Responsible Investment"
#         ]
#       },
#       {
#         "Name": "Good Governance and Ethical Business",
#         "SustainableDevelopmentGoals": ["SDG 12", "SDG 16"],
#         "OverarchingAmbitions": [
#           "Ensure fair, responsible, compliant, and transparent business conduct",
#           "Educate and raise awareness on issues of modern slavery and human trafficking",
#           "Facilitate supply chain stewardship with vendors, partners, managers, and tenants"
#         ],
#         "RelevantMaterialTopics": [
#           "Ethical and Transparent Business",
#           "Compliance with Social and Environmental Regulations",
#           "Safe and Liveable Buildings",
#           "Data Privacy and Cyber Security"
#         ]
#       },
#       {
#         "Name": "Enable Inclusiveness, Safety, Growth and Diversity of Our People",
#         "SustainableDevelopmentGoals": ["SDG 3", "SDG 5", "SDG 8", "SDG 10"],
#         "OverarchingAmbitions": [
#           "Advocate, enable and enhance fair labour practices and employee wellbeing",
#           "Promote safe and healthy workplaces for our people and customers",
#           "Engage with our people and support their growth and development"
#         ],
#         "RelevantMaterialTopics": [
#           "Employment and Employee Engagement",
#           "Health and Safety",
#           "Diversity, Inclusion and Equal Opportunity",
#           "Training and Development",
#           "Fair Labour and Human Rights"
#         ]
#       },
#       {
#         "Name": "Engage Local Communities and Advocate for Positive Impact",
#         "SustainableDevelopmentGoals": ["SDG 10", "SDG 17"],
#         "OverarchingAmbitions": [
#           "Advocate strategic partnerships to enhance sustainability",
#           "Promote positive community engagement"
#         ],
#         "RelevantMaterialTopics": [
#           "Local Community Impact"
#         ]
#       }
#     ],
#     "NewMaterialTopicsForFY2022": [
#       "Emissions Reduction",
#       "Climate Action and Resilience",
#       "Responsible Investment",
#       "Safe and Liveable Buildings",
#       "Data Privacy and Cyber Security",
#       "Fair Labour and Human Rights",
#       "Local Community Impact"
#     ]
#   }
# }
# Processing file: page_4.png
# Extracted JSON for page_4.png: {
#   "report": {
#     "title": "Annual Report 2021",
#     "type": "Sustainability Report",
#     "compliance": "SGX Listing Rules 711B",
#     "standards": "Global Reporting Initiative (GRI) Sustainability Reporting Standards",
#     "organization": "CDLHT",
#     "contact": {
#       "name": "Mr. Paul Kitamura",
#       "position": "Head, Asset Management",
#       "email": "PaulKitamura@cdlht.com"
#     },
#     "website": "www.cdlht.com"
#   },
#   "sustainability": {
#     "vision": "Establishing CDLHT as a premier hospitality and lodging platform with sustainable, innovative, and quality accommodation spaces, generating long term value for our stakeholders.",
#     "mission": "To enable sustainable profitability by acting as responsible stewards of our environmental and social landscapes.",
#     "governance": {
#       "structure": [
#         "Board",
#         "Audit & Risk Committee",
#         "Internal Audit",
#         "CEO",
#         "Sustainability Working Committee (SWC)",
#         "Sustainability Officer",
#         "Operations/Functions"
#       ],
#       "responsibilities": {
#         "Managers' Boards": "Overseeing the integration of sustainability into business goals and strategies, managing and monitoring material ESG factors and performance.",
#         "Audit and Risk Committee (ARC)": "Overseeing sustainability process and strategies, receiving reports from management on sustainability efforts and performance."
#       },
#       "reporting": "Management reports to ARC and Board during quarterly meetings and at the end of each financial year."
#     }
#   }
# }
# Processing file: page_5.png
# Extracted JSON for page_5.png: {
#   "SustainabilityReport": {
#     "SWC": {
#       "Description": "Sustainability Working Committee comprising key personnel from various business functions.",
#       "Leader": "Mr. Vincent Yeo Wee Eng",
#       "Responsibilities": [
#         "Manage and monitor CDLHT’s overall sustainability performance",
#         "Develop strategies incorporating material ESG factors into daily operations"
#       ],
#       "Oversight": "ARC",
#       "FY2021Report": "Reported to the ARC and Managers’ Boards on CDLHT’s sustainability performance",
#       "DataMonitoring": "Portfolio-wide data capture and analysis software for monitoring and tracking performance"
#     },
#     "Guidelines": {
#       "EnvironmentalRiskManagement": {
#         "IssuedBy": "Monetary Authority of Singapore",
#         "EffectiveDate": "June 2022",
#         "Response": "SWC will develop an approach to address these guidelines in consultation with Managers’ Boards and ARCs"
#       }
#     },
#     "StakeholderEngagement": {
#       "Description": "Proactive communication with stakeholders to reflect and address their needs",
#       "FY2021Engagement": {
#         "BoardOfDirectors": {
#           "EngagementApproach": [
#             "Board meetings",
#             "Email communication",
#             "Ad-hoc briefings and consultations with external ESG consultants"
#           ],
#           "KeyTopics": [
#             "Economic performance",
#             "ESG performance & trends",
#             "Risk management",
#             "COVID-19 commercial impacts"
#           ],
#           "Frequency": "Continual Engagement"
#         },
#         "GovernmentAndRegulators": {
#           "EngagementApproach": [
#             "Ad-hoc briefings and consultations",
#             "Participation in surveys and focus groups"
#           ],
#           "KeyTopics": [
#             "Social and environmental related legislation",
#             "Risk management"
#           ],
#           "Frequency": "Continual Engagement"
#         },
#         "HotelEmployees": {
#           "EngagementApproach": [
#             "Training and transition assistance programmes",
#             "Annual employment survey",
#             "Performance and career development reviews"
#           ],
#           "KeyTopics": [
#             "Training and development",
#             "Career development opportunities",
#             "Workplace safety and wellbeing",
#             "COVID-19 safety protocols"
#           ],
#           "Frequency": "Continual Engagement"
#         },
#         "HotelGuests": {
#           "EngagementApproach": [
#             "Customer satisfaction surveys",
#             "Social media",
#             "Feedback via General Manager"
#           ],
#           "KeyTopics": [
#             "Customers’ health and safety",
#             "COVID-19 safety protocols"
#           ],
#           "Frequency": "Continual Engagement"
#         },
#         "MasterLesseesAndHotelManagers": {
#           "EngagementApproach": [
#             "Regular management meetings and communication",
#             "Bilateral communication, one-on-one meetings, and site visits"
#           ],
#           "KeyTopics": [
#             "Workplace safety and wellbeing",
#             "Customer health and safety",
#             "Eco-efficiency of buildings",
#             "COVID-19 commercial impacts"
#           ],
#           "Frequency": "Continual Engagement"
#         },
#         "InvestorsAnalystsAndMedia": {
#           "EngagementApproach": [
#             "Release of financial results and announcements",
#             "Meetings and calls with analysts and media",
#             "Investor conferences / roadshows",
#             "Annual General Meetings",
#             "Annual reports and sustainability reports",
#             "Media releases and interviews",
#             "Responses to investors’ enquiries"
#           ],
#           "KeyTopics": [
#             "Market and operational performance",
#             "Distribution and earnings",
#             "Business strategy and outlook",
#             "Corporate governance",
#             "Regulatory compliance"
#           ],
#           "Frequency": "Continual Engagement"
#         },
#         "HotelSuppliersAndBusinessPartners": {
#           "EngagementApproach": [
#             "Assessment of suppliers and vendors",
#             "Meetings with business partners"
#           ],
#           "KeyTopics": [
#             "Economic performance",
#             "Environmental factors"
#           ],
#           "Frequency": "Periodically"
#         }
#       }
#     }
#   }
# }
# Processing file: page_6.png
# Extracted JSON for page_6.png: {
#   "report": {
#     "title": "Annual Report 2021",
#     "sections": [
#       {
#         "title": "Sustainability Report",
#         "subsections": [
#           {
#             "title": "Materiality Assessment",
#             "details": {
#               "year": "FY 2021",
#               "purpose": "Revamping ESG framework",
#               "process": "Peer investigation and benchmarking",
#               "outcome": {
#                 "core_ESG_pillars": [
#                   {
#                     "pillar": "Climate Resilience and Environmental Stewardship",
#                     "material_topics": [
#                       "Energy Efficiency",
#                       "Water Stewardship",
#                       "Waste",
#                       "Emissions Reduction",
#                       "Climate Action and Resilience"
#                     ]
#                   },
#                   {
#                     "pillar": "Responsible Investment and Sustainable Value",
#                     "material_topics": [
#                       "Economic Performance",
#                       "Responsible Investment"
#                     ]
#                   },
#                   {
#                     "pillar": "Good Governance and Ethical Business",
#                     "material_topics": [
#                       "Ethical and Transparent Business",
#                       "Compliance with Social and Environmental Regulations",
#                       "Safe and Liveable Buildings",
#                       "Data Privacy and Cyber Security"
#                     ]
#                   },
#                   {
#                     "pillar": "Enable Inclusiveness, Safety, Growth and Diversity of Our People",
#                     "material_topics": [
#                       "Employment and Employee Engagement",
#                       "Health and Safety",
#                       "Diversity, Inclusion and Equal Opportunity",
#                       "Training and Development",
#                       "Fair Labour and Human Rights"
#                     ]
#                   },
#                   {
#                     "pillar": "Engage Local Communities and Advocate for Positive Impact",
#                     "material_topics": [
#                       "Local Community Impact"
#                     ]
#                   }
#                 ],
#                 "new_material_topics": [
#                   "Emissions Reductions",
#                   "Climate Action and Resilience",
#                   "Responsible Investment",
#                   "Data Privacy and Security",
#                   "Local Community Impact",
#                   "Safe and Liveable Buildings",
#                   "Fair Labour and Human Rights"
#                 ],
#                 "reporting_commencement": {
#                   "FY_2022": [
#                     "Emissions Reductions",
#                     "Climate Action and Resilience",
#                     "Responsible Investment",
#                     "Data Privacy and Security",
#                     "Local Community Impact"
#                   ],
#                   "FY_2023": [
#                     "Safe and Liveable Buildings",
#                     "Fair Labour and Human Rights"
#                   ]
#                 }
#               }
#             }
#           }
#         ]
#       },
#       {
#         "title": "Climate Resilience and Environmental Stewardship",
#         "details": {
#           "commitment": "Address climate change and its affiliated risks",
#           "goals": [
#             "Conserve natural resources",
#             "Reduce carbon footprint",
#             "Reduce waste generation"
#           ],
#           "focus_area": "Energy Efficiency",
#           "approach": {
#             "portfolio": "Primarily hospitality properties",
#             "initiatives": [
#               "Reduction in energy consumption",
#               "Energy conservation and efficiency",
#               "Active monitoring of consumption patterns",
#               "Operational initiatives",
#               "Retrofitting technological advancements"
#             ]
#           }
#         }
#       }
#     ]
#   }
# }
# Processing file: page_7.png
# Extracted JSON for page_7.png: {
#   "SustainabilityReport": {
#     "EnergyManagement": {
#       "SystemsUsed": ["Building Management System (BMS)", "Energy Management System (EMS)"],
#       "Hotels": [
#         {
#           "Name": "The Lowry Hotel",
#           "Year": "FY 2021",
#           "Action": "Upgraded BMS"
#         },
#         {
#           "Name": "Orchard Hotel",
#           "Actions": [
#             "Reduced operating hours of carpark ventilation",
#             "Switched off non-essential lighting zones",
#             "Limited energy to escalators, air-conditioning, and lighting during low usage"
#           ]
#         },
#         {
#           "Name": "Grand Copthorne Waterfront Hotel",
#           "Action": "Altered air-conditioning temperature design"
#         },
#         {
#           "Name": "Copthorne King’s Hotel",
#           "Action": "Implemented room control systems via EMS"
#         },
#         {
#           "Name": "W Singapore - Sentosa Cove",
#           "Operator": "Marriott International",
#           "Commitment": "2025 Sustainability and Social Impact Goals",
#           "Action": "Optimised energy usage through BMS alterations to chillers and HVAC"
#         }
#       ],
#       "Programs": [
#         {
#           "Name": "Accor’s Planet 21",
#           "FocusAreas": ["Employees", "Customer Involvement", "Innovation with Partners", "Local Communities"]
#         }
#       ]
#     },
#     "TechnologicalAdvancements": {
#       "Actions": [
#         {
#           "Hotel": "Copthorne King’s Hotel",
#           "Upgrade": "Innovative technology system for power, lighting, and air-conditioning",
#           "Acknowledgement": "Government grant"
#         },
#         {
#           "Action": "Replaced halogen lights with LED",
#           "Hotels": ["All hotels", "Grand Copthorne Waterfront Hotel"]
#         },
#         {
#           "Action": "Installed sensor lights for portable assets"
#         },
#         {
#           "Partnership": "City Gas",
#           "Action": "Replace electrical heaters with gas heaters",
#           "EnergySources": ["Methane", "Green Hydrogen"]
#         },
#         {
#           "Partnership": "SP Group’s SP Mobility",
#           "Action": "Install EV vehicle charging stations",
#           "Location": "Singapore hotels",
#           "Timeline": "By Q3 2022"
#         }
#       ],
#       "Platform": {
#         "Name": "Hilton’s LightStay",
#         "Location": "Hilton Cambridge City Centre",
#         "Benefits": [
#           "Motion lighting sensors in gym and toilets",
#           "Low-energy monitors for computers",
#           "95% conversion to LED lighting"
#         ]
#       }
#     }
#   }
# }
# Processing file: page_8.png
# Extracted JSON for page_8.png: {
#   "reports": {
#     "annual_report": "2021",
#     "sustainability_report": {
#       "awards_and_accolades": {
#         "bca_green_mark_award": {
#           "platinum": [
#             "Copthorne King's Hotel",
#             "Grand Copthorne Waterfront Hotel"
#           ],
#           "gold_plus": [
#             "Orchard Hotel",
#             "M Hotel"
#           ],
#           "gold": [
#             "Studio M Hotel"
#           ]
#         },
#         "bizSAFE_certification_level_4": [
#           "Orchard Hotel",
#           "Studio M Hotel"
#         ],
#         "earthcheck_gold_certificate": [
#           "Angsana Velavaru"
#         ],
#         "singapore_green_hotel_award": [
#           "Grand Copthorne Waterfront Hotel",
#           "Studio M Hotel"
#         ]
#       },
#       "performance": {
#         "electricity_consumption": {
#           "FY_2020": {
#             "singapore": 53645,
#             "overseas": 14406
#           },
#           "FY_2021": {
#             "singapore": 58797,
#             "overseas": 20152
#           }
#         },
#         "energy_intensity": {
#           "FY_2020": {
#             "singapore": 0.14,
#             "overseas": 0.08
#           },
#           "FY_2021": {
#             "singapore": 0.08,
#             "overseas": 0.04
#           }
#         },
#         "fuel_consumption": {
#           "FY_2020": {
#             "singapore": 102254,
#             "overseas": 5274
#           },
#           "FY_2021": {
#             "singapore": 101374,
#             "overseas": 12276
#           }
#         }
#       },
#       "notes": [
#         "Restated electricity consumption values for FY 2020 due to incomplete data and separation of fuel consumption.",
#         "Energy intensity metric changed from kWh/m² to MWh/m² in FY 2021.",
#         "GFA for Singapore's Energy Intensity in FY 2021 increased due to inclusion of Claymore Connect.",
#         "GFA for Overseas Energy Intensity in FY 2021 increased due to inclusion of Ibis Perth and Mercure Perth.",
#         "Diesel conversion: 1 litre = 38 Megajoules."
#       ]
#     }
#   }
# }
# Processing file: page_9.png
# Extracted JSON for page_9.png: {
#   "SustainabilityReport": {
#     "Targets": {
#       "EnergyReduction": {
#         "Goal": "5% - 7% reduction",
#         "TimeFrame": "next five years",
#         "BaselineYear": "FY 2019"
#       }
#     },
#     "WaterStewardship": {
#       "Objective": "Implement water management and conservation initiatives",
#       "Approach": {
#         "ConservationPolicies": "Included in environmental policies across all hotels",
#         "Compliance": "With regulatory bodies",
#         "OperationalControl": "Mechanisms to curb water consumption",
#         "TechnologicalAdvancements": "To improve water efficiency",
#         "WaterRecycling": "Initiatives to promote sustainable development"
#       },
#       "OperationalControl": {
#         "Monitoring": "Daily water usage monitoring",
#         "Response": "Immediate response to abnormal spikes",
#         "HotelsInSingapore": {
#           "GrandCopthorneWaterfrontHotel": {
#             "Systems": "Water management systems for hand basins and showers"
#           },
#           "OrchardHotel": {
#             "CoolingTower": "Utilises one cooling tower"
#           },
#           "CopthorneKingsHotel": {
#             "CoolingTower": "Utilises one cooling tower"
#           },
#           "MHotel": {
#             "CoolingTower": "Utilises one cooling tower"
#           }
#         },
#         "WHotel": {
#           "ConservationInitiatives": "Target laundry and landscape watering"
#         }
#       },
#       "TechnologicalAdvancements": {
#         "WaterPressureReducers": "Installed across basins, cisterns, and shower heads",
#         "WaterConsumptionRestrictors": "Installed across basins, cisterns, and shower heads",
#         "CopthorneKingsHotel": {
#           "Upgrades": "Replaced all taps and showerheads with water efficient ones"
#         }
#       },
#       "WaterRecycling": {
#         "RainwaterHarvesting": {
#           "WHotel": "Used for landscape purposes",
#           "AngsanaVelavaru": "Used for gardening purposes"
#         }
#       }
#     }
#   }
# }
# Processing file: page_10.png
# Extracted JSON for page_10.png: {
#   "reports": [
#     {
#       "type": "Annual Report",
#       "year": 2021
#     },
#     {
#       "type": "Sustainability Report",
#       "year": 2021,
#       "performance": {
#         "water": {
#           "total_consumption": {
#             "FY_2020": {
#               "Singapore": 372836,
#               "Overseas": 235788,
#               "Total": 608624
#             },
#             "FY_2021": {
#               "Singapore": 309109,
#               "Overseas": 194044,
#               "Total": 503153
#             }
#           },
#           "intensity": {
#             "FY_2020": {
#               "Singapore": 1.96,
#               "Overseas": 1.28,
#               "Total": 1.62
#             },
#             "FY_2021": {
#               "Singapore": 1.56,
#               "Overseas": 0.37,
#               "Total": 0.69
#             }
#           },
#           "targets": {
#             "reduction_goal": "2% - 7%",
#             "baseline_year": 2019
#           }
#         },
#         "waste": {
#           "approach": "Initiatives targeting direct reduction of waste output, waste segregation and recycling.",
#           "initiatives": [
#             {
#               "hotel": "Grand Copthorne Waterfront Hotel",
#               "initiative": "Food digester converts food waste into water."
#             },
#             {
#               "hotel": "Angsana Velavaru",
#               "initiative": "Island-wide ban on single-use plastic bottles."
#             },
#             {
#               "hotels": ["Mercure Perth", "Ibis Perth"],
#               "initiative": "Elimination of plastics and plastic guest amenities through dispensers."
#             }
#           ]
#         }
#       },
#       "notes": [
#         "Restatement of water consumption values for FY 2020 due to incomplete data from some hotels.",
#         "GFA used to calculate Singapore’s Water Intensity in FY 2021 includes Claymore Connect.",
#         "GFA used to calculate Energy Intensity in FY 2021 includes Ibis Perth and Mercure Perth."
#       ]
#     }
#   ]
# }
# Processing file: page_11.png
# Extracted JSON for page_11.png: {
#   "SustainabilityReport": {
#     "WasteSegregationAndRecycling": {
#       "HotelsInvolved": [
#         "W Hotel",
#         "Raffles Maldives Meradhoo"
#       ],
#       "Practices": [
#         {
#           "Hotel": "W Hotel",
#           "Practice": "Recycles and reuses wet waste for landscaping through composting"
#         },
#         {
#           "Hotel": "Raffles Maldives Meradhoo",
#           "Practice": "Uses recycled materials for operating an organic garden"
#         }
#       ]
#     },
#     "AdvocacyForRecycling": {
#       "AwarenessCampaigns": [
#         "Food waste reduction",
#         "Recycling programs for paper, glassware, and plastic waste"
#       ],
#       "DepartmentsInvolved": [
#         "Housekeeping",
#         "Food & Beverage",
#         "Engineering"
#       ],
#       "Policies": [
#         {
#           "Hotel": "Angsana Velavaru",
#           "Policy": "Reduce, Reuse and Recycle",
#           "Practices": [
#             "Utilizing reusable glass bottles and dispensers",
#             "Investing in biodegradable items like garbage bags and cling films"
#           ]
#         },
#         {
#           "Hotel": "Hilton Cambridge City Centre",
#           "Initiative": "#RefuseTheStraw",
#           "Practices": [
#             "Shift towards biodegradable straws",
#             "Elimination of plastic use"
#           ]
#         }
#       ]
#     },
#     "Performance": {
#       "WasteGeneration": "Non-hazardous sources including paper, glass, and food",
#       "WasteByTypeAndDisposalMethodFY2021": {
#         "Singapore": {
#           "Recycling": 64616.3,
#           "Landfill": 267.58,
#           "Others": 13.81,
#           "TotalWaste": 64897.69
#         },
#         "Overseas": {
#           "Recycling": 45.37,
#           "Landfill": 270997.87,
#           "Others": 3.96,
#           "TotalWaste": 271047.20
#         },
#         "AllHotels": {
#           "Recycling": 64661.67,
#           "Landfill": 271265.45,
#           "Others": 17.77,
#           "TotalWaste": 335944.89
#         }
#       }
#     },
#     "Targets": {
#       "BaselineYear": "FY 2021",
#       "FuturePlans": [
#         {
#           "Hotel": "W Hotel",
#           "Plan": "Implement a food management system to manage buffet food waste by FY 2022"
#         },
#         {
#           "Hotels": [
#             "Raffles Maldives Meradhoo",
#             "Angsana Velavaru"
#           ],
#           "Plan": "Implement eco-digester by FY 2022"
#         }
#       ]
#     }
#   }
# }
# Processing file: page_12.png
# Extracted JSON for page_12.png: {
#   "report": {
#     "title": "Annual Report 2021",
#     "sections": [
#       {
#         "title": "Sustainability Report",
#         "content": "Responsible Investment and Sustainable Value",
#         "details": "CDLHT acknowledges the growing shift towards responsible investing resulting from increased demand for transparent, sustainable, and ethical investments. As our hotels operate across numerous geographies, we remain vigilant in tracking our environmental and social impacts, risks and opportunities across our business value chain and operational scopes. We are able to create sustainable value through the incorporation of ESG material topics within our economic performance, investments, and business considerations, strategically adopting a holistic business approach that contributes to the betterment of the communities in which we have a presence. We aim to employ our capital to positively impact society and the environment toward a sustainable future."
#       },
#       {
#         "title": "Economic Performance",
#         "content": "As a leading hospitality trust, ensuring economic growth is paramount to the longevity of our business. Our primary economic objectives are to maximise the rate of return of Stapled Security Holders whilst ensuring regular distributions. The financial summary of FY 2021’s operations, revenues and costs are highlighted on pages 135 to 249, in our annual report.",
#         "strategies": [
#           {
#             "name": "Acquisition Growth Strategy",
#             "details": [
#               "Pursue quality assets with growth potential",
#               "Adopt a medium to long term perspective to ride through market cycles",
#               "Partner with or tap on potential pipeline from M&C / CDL",
#               "Capitalise on historically low interest rates in certain markets to enjoy spread over funding costs"
#             ]
#           },
#           {
#             "name": "Asset Management Strategy",
#             "details": [
#               "Work closely with master lessees, hotel/property managers and/or operators to implement active revenue and cost management",
#               "Implement asset enhancement initiatives to optimise asset potential"
#             ]
#           },
#           {
#             "name": "Capital Recycling Strategy",
#             "details": [
#               "Evaluate divestment opportunities periodically to recycle capital for better returns, rebalance portfolio and/or unlock underlying asset values",
#               "Continually improve quality of portfolio"
#             ]
#           },
#           {
#             "name": "Capital Management Strategy",
#             "details": [
#               "Maintain a healthy balance sheet",
#               "Enhance financial flexibility by maintaining diversified sources of funding",
#               "Manage exposure arising from interest rates and foreign exchange through appropriate hedging strategies"
#             ]
#           }
#         ]
#       }
#     ],
#     "financial_summary": {
#       "pages": "135 to 249"
#     },
#     "keywords": [
#       "Financial Foundation",
#       "Recycle Capital",
#       "Acquisition",
#       "Organic Growth"
#     ]
#   }
# }
# Processing file: page_13.png
# Extracted JSON for page_13.png: {
#   "report": "Sustainability Report",
#   "sections": [
#     {
#       "title": "Good Governance and Ethical Business",
#       "description": "Ensuring fair, responsible, compliant, and transparent business conduct to build trust and loyalty with stakeholders.",
#       "approach": "Commitment to corporate governance, ethical business practices, and compliance with regulatory legislations."
#     },
#     {
#       "title": "Ethical and Transparent Business",
#       "description": "Upholding integrity and ethical standards through corporate governance, responsible business practices, accountability, and transparent management systems.",
#       "approach": "Mandatory compliance training, adoption of policies, and monitoring implementation.",
#       "policies": [
#         "Anti-Bribery Policy",
#         "Anti-Corruption Compliance Guide",
#         "Business Hospitality and Gifts Policy",
#         "Whistleblowing Policy",
#         "Ethics and Corporate Social Responsibility Charter",
#         "Corporate Communications",
#         "Global Data Protection",
#         "Related Party Transactions"
#       ],
#       "monitoring_processes": [
#         "Regular screening of laws and regulations",
#         "Contract compliance review by Legal department",
#         "Reporting suspected violations",
#         "Oversight of non-compliance issues",
#         "Incident documentation",
#         "Open-door policy for reporting"
#       ],
#       "performance": {
#         "FY_2021": {
#           "misconduct_cases": 0,
#           "non_compliance_cases": 0,
#           "fines_or_sanctions": 0
#         }
#       },
#       "targets": "Maintain zero incidences of corruption, bribery, and misconduct. Conduct training for new hires and update employees on new policies."
#     },
#     {
#       "title": "Compliance with Social and Environmental Regulations",
#       "description": "Remaining compliant with social and environmental regulations globally.",
#       "approach": "Monitoring changes through monthly interactions with hotel operating partners.",
#       "performance": {
#         "FY_2021": {
#           "non_compliance_cases": 0,
#           "fines_or_sanctions": 0
#         }
#       }
#     }
#   ]
# }
# Processing file: page_14.png
# Extracted JSON for page_14.png: {
#   "report": {
#     "title": "Annual Report 2021",
#     "type": "Sustainability Report",
#     "organization": "CDLHT",
#     "targets": {
#       "compliance": "Maintain zero incidences of non-compliance with social and environmental laws or regulations resulting in significant fines and sanctions."
#     },
#     "employee_focus": {
#       "inclusiveness": "Enable inclusiveness, safety, growth, and diversity of employees.",
#       "health_safety": "Create a conducive, safe, and engaging working environment, especially during the pandemic.",
#       "employment_engagement": {
#         "commitment": "Balance job and talent retention while ensuring wellbeing and meaningful engagement.",
#         "standards": "Uphold fair employment standards and competitive remuneration based on merit and compliance with the law."
#       },
#       "approach": {
#         "practices": [
#           "Diversity Policy",
#           "Fair and merit-based employment and recruitment practices",
#           "Policies on performance evaluation and career development",
#           "Tripartite Alliance for Fair and Progressive Employment Practices (TAFEP)",
#           "Fair and competitive remuneration based on merit"
#         ],
#         "feedback": "Collate employee feedback via staff dialogue to understand key areas of concern.",
#         "integration": "Conduct meetings at the start of employment to understand employee integration.",
#         "exit_interview": "Conduct exit interviews to receive feedback on areas of concern.",
#         "employee_handbook": "Disseminate handbook detailing policies and procedures.",
#         "induction_onboarding": "Ensure proper induction and onboarding of all staff."
#       },
#       "wellbeing": {
#         "challenges": "Address physical and mental challenges due to the pandemic.",
#         "initiatives": [
#           {
#             "hotel": "Copthorne King’s Hotel",
#             "activities": "Conducted virtual classes targeting mental and physical health."
#           },
#           {
#             "hotel": "W Hotel",
#             "activities": "Conducted monthly activities such as virtual games and scenic walks in nature."
#           },
#           {
#             "hotel": "Angsana Velavaru",
#             "activities": "Conducted wellbeing initiatives including sports and awareness activities."
#           },
#           {
#             "hotel": "The Lowry Hotel",
#             "activities": "Encouraged departmental outings and provided motivational gifts."
#           }
#         ]
#       }
#     }
#   }
# }
# Processing file: page_15.png
# Extracted JSON for page_15.png: {
#   "Performance": {
#     "FY_2021": {
#       "Total_Employees": 827,
#       "Gender_Distribution": {
#         "Male": 58,
#         "Female": 42
#       },
#       "Employees_Left": 673,
#       "Turnover_Gender_Distribution": {
#         "Male": 60,
#         "Female": 40
#       },
#       "New_Hire_Rate": 16,
#       "Turnover_Rate": 13
#     }
#   },
#   "New_Employee_Hires_and_Turnover": {
#     "Singapore": {
#       "Male": {
#         "New_Hires": 178,
#         "Hire_Rate": 3.57,
#         "Turnover": 181,
#         "Turnover_Rate": 3.63
#       },
#       "Female": {
#         "New_Hires": 118,
#         "Hire_Rate": 2.36,
#         "Turnover": 130,
#         "Turnover_Rate": 2.60
#       }
#     },
#     "Overseas": {
#       "Male": {
#         "New_Hires": 298,
#         "Hire_Rate": 5.97,
#         "Turnover": 155,
#         "Turnover_Rate": 3.10
#       },
#       "Female": {
#         "New_Hires": 233,
#         "Hire_Rate": 4.67,
#         "Turnover": 221,
#         "Turnover_Rate": 4.43
#       }
#     },
#     "All_Hotels": {
#       "Male": {
#         "New_Hires": 476,
#         "Hire_Rate": 9.5,
#         "Turnover": 402,
#         "Turnover_Rate": 8.1
#       },
#       "Female": {
#         "New_Hires": 351,
#         "Hire_Rate": 7.0,
#         "Turnover": 271,
#         "Turnover_Rate": 5.4
#       }
#     }
#   },
#   "Targets": {
#     "Pandemic_Impact": "Volatile labour markets affecting specific targets",
#     "Goal": "Minimize turnover rate to retain talent"
#   },
#   "Health_and_Safety": {
#     "Commitment": "Adhering to and enforcing workplace health and safety standards",
#     "Approach": {
#       "Monitoring": "CDLHT monitors safety measures by hotel operators",
#       "Compliance": "Ensuring adherence to local regulations and guidelines",
#       "Communication": "Regular communication with hotel operators on compliance and safety",
#       "Incident_Management": "Investigation and risk assessment for work-related injuries",
#       "Annual_Review": "Conduct annual review to strengthen health and safety standards"
#     },
#     "OH&S_Training_and_Communication": {
#       "Applicability": "Policies applicable to employees, visitors, and contractors",
#       "Responsibility": "Managers and supervisors ensure OH&S compliance"
#     },
#     "Initiatives": [
#       "Risk assessments",
#       "Certified accreditation",
#       "Measures to curb COVID-19 spread"
#     ]
#   }
# }
# Processing file: page_16.png
# Extracted JSON for page_16.png: {
#   "reports": [
#     {
#       "title": "Annual Report 2021"
#     },
#     {
#       "title": "Sustainability Report"
#     }
#   ],
#   "OH&S_Risk_Assessments": {
#     "description": "Workplace risk assessments are carried out to identify potential hazards, determining employees, jobs or equipment that are of high risk. Our hotels conduct risk assessments for routine and non-routine work activities to prevent affiliated hazards.",
#     "specific_hotels": [
#       {
#         "name": "Orchard Hotel",
#         "location": "Singapore",
#         "activity": "Conduct risk assessments for new equipment"
#       }
#     ]
#   },
#   "Accreditation": [
#     {
#       "hotel": "Grand Copthorne Waterfront Hotel",
#       "certification": "Bizsafe Level 4 Certification"
#     },
#     {
#       "hotel": "W Hotel",
#       "location": "Singapore",
#       "certification": "SG Clean Certified"
#     },
#     {
#       "hotel": "Pullman Hotel Munich",
#       "certification": "HACCP"
#     }
#   ],
#   "COVID-19_Measures": {
#     "location": "Singapore hotels",
#     "measures": [
#       "Work-from-home practices",
#       "Virtual meetings",
#       "Split team arrangements",
#       "Antigen Rapid Tests (ART)",
#       "Social distancing",
#       "Restrictive mingling at common gathering areas",
#       "Retrofitted and enhanced air handling units"
#     ],
#     "overseas_hotels": "Similar measures implemented"
#   },
#   "Performance_FY_2021": {
#     "work_related_injuries": {
#       "fatalities": 0,
#       "high_consequence_injuries": 42,
#       "recordable_injuries": 91,
#       "total_injuries": 133
#     },
#     "hours_worked": 2600000,
#     "injury_rates": {
#       "fatalities_rate": 0,
#       "high_consequence_injury_rate": 3.19,
#       "recordable_injury_rate": 6.9
#     }
#   },
#   "notes": {
#     "high_consequence_injuries": "Includes number of dangerous occurrences, incidents exceeding three days of medical leave, incidents of hospitalisation, occupational disease, and/or permanent disabilities.",
#     "recordable_injuries": "Includes number of incidents that required less than three days of medical leave, reportable incidents, and/or temporary disabilities."
#   }
# }
# Processing file: page_17.png
# Extracted JSON for page_17.png: {
#   "SustainabilityReport": {
#     "Targets": {
#       "Safety": "Zero incidents of fatality or permanent disability and minimizing work-related injuries",
#       "Diversity": "Reflect diversity across workforce and hiring processes, increase diversity in management roles"
#     },
#     "DiversityInclusionEqualOpportunity": {
#       "Objective": "Foster diversity and inclusion in the workplace",
#       "Approach": "Driven by policies of hotel portfolio managers",
#       "Recognition": "Hilton Cambridge City Centre recognized as LGBTQ+ led hotel",
#       "Training": "Diversity, Inclusion and Unconscious Bias training for all employees"
#     },
#     "DiversityInclusionDataFY2021": {
#       "Employees": {
#         "PermanentStaff": {
#           "Singapore": {
#             "Male": 473,
#             "Female": 299
#           },
#           "Overseas": {
#             "Male": 2913,
#             "Female": 634
#           },
#           "AllHotels": {
#             "Male": 3386,
#             "Female": 933
#           }
#         },
#         "TemporaryStaff": {
#           "Singapore": {
#             "Male": 62,
#             "Female": 37
#           },
#           "Overseas": {
#             "Male": 633,
#             "Female": 157
#           },
#           "AllHotels": {
#             "Male": 695,
#             "Female": 194
#           }
#         }
#       },
#       "AgeDistribution": {
#         "AgedUnder30": {
#           "Singapore": 178,
#           "Overseas": 342,
#           "AllHotels": 520
#         },
#         "Aged30To50": {
#           "Singapore": 442,
#           "Overseas": 401,
#           "AllHotels": 843
#         },
#         "AgedOver50": {
#           "Singapore": 163,
#           "Overseas": 102,
#           "AllHotels": 265
#         }
#       }
#     },
#     "PerformanceFY2021": {
#       "TemporaryStaffGenderDistribution": {
#         "Male": "78%",
#         "Female": "22%"
#       },
#       "AgeDistribution": {
#         "Under30": "32%",
#         "Between30And50": "52%"
#       }
#     }
#   }
# }
# Processing file: page_18.png
# Extracted JSON for page_18.png: {
#   "report": {
#     "title": "Annual Report 2021",
#     "type": "Sustainability Report",
#     "sections": [
#       {
#         "title": "Training and Development",
#         "description": "Focus on continuous training and development of employees to promote a resilient, competitive, and upskilled workforce."
#       },
#       {
#         "title": "Our Approach",
#         "description": "Bi-annual performance reviews, informal mid-year review, formal year-end performance appraisal, and establishment of KPIs."
#       },
#       {
#         "title": "Training and Upskilling Opportunities",
#         "description": "General orientation, mandatory training courses, training needs analysis, and specialized training courses including leadership training."
#       },
#       {
#         "title": "Job Redesign",
#         "description": "Cross-functional training initiative at Orchard Hotel and W Hotel in Singapore, supported by the Singapore government."
#       },
#       {
#         "title": "Our Performance",
#         "metrics": {
#           "average_training_hours": {
#             "Singapore": {
#               "male": 4.87,
#               "female": 4.57
#             },
#             "Overseas": {
#               "male": 0.06,
#               "female": 0.09
#             },
#             "All Hotels": {
#               "male": 4.96,
#               "female": 4.67
#             }
#           },
#           "total_employees": {
#             "Singapore": {
#               "male": 535,
#               "female": 336
#             },
#             "Overseas": {
#               "male": 3546,
#               "female": 791
#             },
#             "All Hotels": {
#               "male": 4081,
#               "female": 1127
#             }
#           },
#           "total_training_hours": {
#             "Singapore": {
#               "male": 16420,
#               "female": 15435
#             },
#             "Overseas": {
#               "male": 306,
#               "female": 310
#             },
#             "All Hotels": {
#               "male": 16726,
#               "female": 15745
#             }
#           }
#         }
#       },
#       {
#         "title": "Our Targets",
#         "description": "Aim to continuously achieve an increasing average number of training hours per employee, annually."
#       }
#     ]
#   }
# }
# Processing file: page_19.png
# Extracted JSON for page_19.png: {
#   "SustainabilityReport": {
#     "EngageLocalCommunities": {
#       "LocalCommunityImpact": {
#         "RafflesMaldivesMeradhoo": {
#           "Activities": [
#             "Employee participation in cleaning activities for the island",
#             "Nurturing of local youth",
#             "Painting local schools",
#             "Celebrating 'No Plastic Day' with school children"
#           ]
#         },
#         "TheLowryHotel": {
#           "CharitiesSupported": [
#             {
#               "Name": "Wood Street Mission",
#               "Purpose": "Aiding local families and children living on a low income in the Manchester and Salford area",
#               "SupportDetails": {
#                 "YearsSupported": 7,
#                 "AnnualFundsRaised": "$5,000 to $10,000",
#                 "Activities": [
#                   "Hosting Christmas lunch for 30 children",
#                   "Assisting with toy and book collections",
#                   "Creating hampers for Christmas and Easter"
#                 ]
#               }
#             },
#             {
#               "Name": "Mustard Tree",
#               "Purpose": "Assisting the homeless within Manchester city",
#               "SupportDetails": {
#                 "YearsSupported": 4,
#                 "Activities": [
#                   "Food and drink donations",
#                   "Employee volunteering for food banks and soup kitchens",
#                   "Donation drives",
#                   "Supporting Christmas Crate Campaign"
#                 ]
#               }
#             }
#           ]
#         },
#         "HiltonCambridgeCityCentre": {
#           "Donations": [
#             "Toiletries, personal protective equipment, food, drinks, toys and apparel to NHS Hospital maternity ward",
#             "Fruit and vegetable baskets for medical staff through Spectrum charity"
#           ],
#           "CharitySupported": {
#             "Name": "Spectrum",
#             "Purpose": "Supporting over 30,000 families with autistic children",
#             "Activities": [
#               "Charity fundraising events",
#               "Entertainment parties",
#               "Black-tie balls at discounted rates"
#             ]
#           },
#           "RecyclingInitiative": "Donating and recycling lost and found property to a local Cambridge charity for the homeless"
#         }
#       }
#     },
#     "Targets": {
#       "CommunityEventProject": "Conduct at least one community event/project for 60% of the hotel portfolio for FY 2022"
#     }
#   }
# }
# Processing file: page_20.png
# Extracted JSON for page_20.png: {
#   "report": "Annual Report 2021",
#   "sections": [
#     {
#       "title": "Sustainability Report",
#       "subsections": [
#         {
#           "title": "GRI Content Index",
#           "categories": [
#             {
#               "category": "General Disclosures",
#               "GRI Standard": "GRI 2: General Disclosures 2021",
#               "disclosures": [
#                 {
#                   "disclosure": "2-1 Organisational details",
#                   "page_number": 113
#                 },
#                 {
#                   "disclosure": "2-2 Entities included in the organization’s sustainability reporting",
#                   "page_number": [114, 116]
#                 },
#                 {
#                   "disclosure": "2-3 Reporting period, frequency, and contact point",
#                   "page_number": 116
#                 },
#                 {
#                   "disclosure": "2-4 Restatements of Information",
#                   "page_number": [120, 122]
#                 },
#                 {
#                   "disclosure": "2-5 External Assurance",
#                   "page_number": "N/A"
#                 },
#                 {
#                   "disclosure": "2-6 Activities, value chain and other business relationships",
#                   "page_number": 114
#                 },
#                 {
#                   "disclosure": "2-7 Employees",
#                   "page_number": 129
#                 },
#                 {
#                   "disclosure": "2-8 Workers who are not employees",
#                   "page_number": 129
#                 },
#                 {
#                   "disclosure": "2-9 Governance structure and composition",
#                   "page_number": [116, 125]
#                 },
#                 {
#                   "disclosure": "2-10 Nomination and selection of the highest governance body",
#                   "page_number": 125
#                 },
#                 {
#                   "disclosure": "2-12 Role of the highest governance body in overseeing the management of impacts",
#                   "page_number": 125
#                 },
#                 {
#                   "disclosure": "2-13 Delegation of responsibility for managing impacts",
#                   "page_number": [116, 125]
#                 },
#                 {
#                   "disclosure": "2-14 Role of the highest governance body in sustainability reporting",
#                   "page_number": 116
#                 },
#                 {
#                   "disclosure": "2-16 Communication of critical concerns",
#                   "page_number": 116
#                 },
#                 {
#                   "disclosure": "2-17 Collective knowledge of the highest governance body",
#                   "page_number": 116
#                 },
#                 {
#                   "disclosure": "2-18 Evaluation of the performance of the highest governance body",
#                   "page_number": 116
#                 },
#                 {
#                   "disclosure": "2-22 Statement on sustainable development strategy",
#                   "page_number": 114
#                 },
#                 {
#                   "disclosure": "2-26 Mechanisms for seeking advice and raising concerns",
#                   "page_number": 125
#                 },
#                 {
#                   "disclosure": "2-27 Compliance with laws and regulations",
#                   "page_number": 125
#                 },
#                 {
#                   "disclosure": "2-28 Membership associations",
#                   "page_number": "N/A"
#                 },
#                 {
#                   "disclosure": "2-29 Approach to stakeholder engagement",
#                   "page_number": 117
#                 }
#               ]
#             },
#             {
#               "category": "Disclosures on Material Topics",
#               "GRI Standard": "GRI 3: Material Topics 2021",
#               "disclosures": [
#                 {
#                   "disclosure": "3-1 Process to determine material topics",
#                   "page_number": 118
#                 },
#                 {
#                   "disclosure": "3-2 List of material topics",
#                   "page_number": 118
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }
# Processing file: page_21.png
# Extracted JSON for page_21.png: {
#   "SustainabilityReport": {
#     "Organization": "CDL Hospitality Trusts",
#     "MaterialTopics": {
#       "Energy": {
#         "GRIStandard": "GRI 302: Energy 2016",
#         "Disclosures": {
#           "302-1": {
#             "Description": "Energy consumption within the organisation",
#             "PageNumber": "120"
#           },
#           "302-3": {
#             "Description": "Energy intensity",
#             "PageNumber": "120"
#           },
#           "302-4": {
#             "Description": "Reduction of energy consumption",
#             "PageNumber": "120"
#           }
#         },
#         "Management": {
#           "GRIStandard": "GRI 3: Material Topics 2021",
#           "Disclosure": "3-3 Management of material topics",
#           "PageNumber": "118-120"
#         }
#       },
#       "WaterAndEffluents": {
#         "GRIStandard": "GRI 303: Water and Effluents 2018",
#         "Disclosures": {
#           "303-3": {
#             "Description": "Water withdrawal",
#             "PageNumber": "122"
#           },
#           "303-5": {
#             "Description": "Water consumption",
#             "PageNumber": "122"
#           }
#         },
#         "Management": {
#           "GRIStandard": "GRI 3: Material Topics 2021",
#           "Disclosure": "3-3 Management of material topics",
#           "PageNumber": "121-122"
#         }
#       },
#       "EffluentsAndWaste": {
#         "GRIStandard": "GRI 306: Effluents and Waste 2016",
#         "Disclosures": {
#           "306-3": {
#             "Description": "Waste by type and disposal method",
#             "PageNumber": "123"
#           }
#         },
#         "Management": {
#           "GRIStandard": "GRI 3: Material Topics 2021",
#           "Disclosure": "3-3 Management of material topics",
#           "PageNumber": "122-123"
#         }
#       },
#       "EconomicPerformance": {
#         "GRIStandard": "GRI 201: Economic Performance 2016",
#         "Disclosures": {
#           "201-1": {
#             "Description": "Direct economic value generated and distributed",
#             "Reference": "Refer to Annual Report"
#           },
#           "201-2": {
#             "Description": "Financial implications and other risks and opportunities due to climate change",
#             "Reference": "Refer to Annual Report"
#           },
#           "201-3": {
#             "Description": "Defined benefit plan obligations and other retirement plans",
#             "Reference": "Refer to Annual Report"
#           },
#           "201-4": {
#             "Description": "Financial assistance received from government",
#             "Reference": "Refer to Annual Report"
#           }
#         },
#         "Management": {
#           "GRIStandard": "GRI 3: Material Topics 2021",
#           "Disclosure": "3-3 Management of material topics",
#           "Reference": "Refer to Annual Report"
#         }
#       },
#       "AntiCorruption": {
#         "GRIStandard": "GRI 205: Anti-corruption 2016",
#         "Disclosures": {
#           "205-2": {
#             "Description": "Communication and training about anti-corruption policies and procedures",
#             "PageNumber": "125-126"
#           },
#           "205-3": {
#             "Description": "Confirmed incidents of corruption and actions taken",
#             "PageNumber": "125"
#           }
#         },
#         "Management": {
#           "GRIStandard": "GRI 3: Material Topics 2021",
#           "Disclosure": "3-3 Management of material topics",
#           "PageNumber": "125-126"
#         }
#       },
#       "AntiCompetitiveBehaviour": {
#         "GRIStandard": "GRI 206: Anti-competitive Behavior 2016",
#         "Disclosures": {
#           "206-1": {
#             "Description": "Legal actions for anti-competitive behavior, anti-trust, and monopoly practices",
#             "PageNumber": "125"
#           }
#         },
#         "Management": {
#           "GRIStandard": "GRI 3: Material Topics 2021",
#           "Disclosure": "3-3 Management of material topics",
#           "PageNumber": "125-126"
#         }
#       }
#     }
#   }
# }
# Processing file: page_22.png
# Extracted JSON for page_22.png: {
#   "report": {
#     "title": "Annual Report 2021",
#     "sections": [
#       {
#         "title": "Sustainability Report",
#         "topics": [
#           {
#             "name": "Employment",
#             "GRI_Standard": "GRI 401: Employment 2016",
#             "disclosures": [
#               {
#                 "code": "401-1",
#                 "description": "New employee hires and employee turnover",
#                 "page_number": "127"
#               }
#             ],
#             "management": {
#               "GRI_Standard": "GRI 3: Material Topics 2021",
#               "disclosure": "3-3 Management of material topics",
#               "page_numbers": "126-127"
#             }
#           },
#           {
#             "name": "Occupational Health and Safety",
#             "GRI_Standard": "GRI 403: Occupational Health and Safety 2018",
#             "disclosures": [
#               {
#                 "code": "403-1",
#                 "description": "Occupational health and safety management system",
#                 "page_numbers": "127-128"
#               },
#               {
#                 "code": "403-2",
#                 "description": "Hazard identification, risk assessment, and incident investigation",
#                 "page_numbers": "127-128"
#               },
#               {
#                 "code": "403-9",
#                 "description": "Work-related injuries",
#                 "page_number": "128"
#               }
#             ],
#             "management": {
#               "GRI_Standard": "GRI 3: Material Topics 2021",
#               "disclosure": "3-3 Management of material topics",
#               "page_numbers": "127-129"
#             }
#           },
#           {
#             "name": "Diversity, Inclusion and Equal Opportunity",
#             "GRI_Standard": "GRI 405: Diversity and Equal Opportunity 2016",
#             "disclosures": [
#               {
#                 "code": "405-1",
#                 "description": "Diversity of governance bodies and employees",
#                 "page_numbers": "129-130"
#               }
#             ],
#             "management": {
#               "GRI_Standard": "GRI 3: Material Topics 2021",
#               "disclosure": "3-3 Management of material topics",
#               "page_numbers": "129-130"
#             }
#           },
#           {
#             "name": "Training and Education",
#             "GRI_Standard": "GRI 404: Training and Education 2016",
#             "disclosures": [
#               {
#                 "code": "404-1",
#                 "description": "Average hours of training per year per employee",
#                 "page_number": "129"
#               }
#             ],
#             "management": {
#               "GRI_Standard": "GRI 3: Material Topics 2021",
#               "disclosure": "3-3 Management of material topics",
#               "page_numbers": "129-130"
#             }
#           },
#           {
#             "name": "Local Communities",
#             "GRI_Standard": "GRI 413: Local Communities 2016",
#             "disclosures": [
#               {
#                 "code": "413-1",
#                 "description": "Operations with local community engagement, impact assessments, and development programs",
#                 "page_number": "131"
#               }
#             ],
#             "management": {
#               "GRI_Standard": "GRI 3: Material Topics 2021",
#               "disclosure": "3-3 Management of material topics",
#               "page_number": "131"
#             }
#           }
#         ]
#       }
#     ]
#   }
# }
# JSON data saved to gpt-4o/extracted_data.json
